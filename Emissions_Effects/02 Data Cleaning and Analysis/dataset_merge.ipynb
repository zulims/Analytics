# %%
import pandas as pd
import csv

# %%
calarb = pd.read_csv('calarb_table.csv')
ces = pd.read_csv('ces3results.csv')

# %%
ces.head()
# Out:
#    Census Tract  Total Population California County    ZIP      City  \
# 0    6019001100              3174           Fresno   93706    Fresno
# 1    6071001600              6133    San Bernardino  91761   Ontario
# 2    6019000200              3167           Fresno   93706    Fresno
# 3    6077000801              6692       San Joaquin  95203  Stockton
# 4    6019001500              2206           Fresno   93725    Fresno
#
#     Longitude   Latitude  CES 3.0 Score   CES 3.0 Percentile  \
# 0 -119.781696  36.709695          94.09               100.00
# 1 -117.618013  34.057780          90.68                99.99
# 2 -119.805504  36.735491          85.97                99.97
# 3 -121.314524  37.940517          82.49                99.96
# 4 -119.717843  36.681600          82.03                99.95
#
#   CES 3.0 \nPercentile Range       ...         Linguistic Isolation Pctl  \
# 0   96-100% (highest scores)       ...                             77.51
# ...

# %%
combined_data = pd.merge(calarb, ces, on="California County", how='left')
combined_data
# Out:
#      California County  Heating & Power  Transportation  Dust & Fire  \
# 0             Alameda          1.433822          2.8607       0.9410
# 1             Alameda          1.433822          2.8607       0.9410
# 2             Alameda          1.433822          2.8607       0.9410
# 3             Alameda          1.433822          2.8607       0.9410
# 4             Alameda          1.433822          2.8607       0.9410
# 5             Alameda          1.433822          2.8607       0.9410
# 6             Alameda          1.433822          2.8607       0.9410
# 7             Alameda          1.433822          2.8607       0.9410
# 8             Alameda          1.433822          2.8607       0.9410
# 9             Alameda          1.433822          2.8607       0.9410
# 10            Alameda          1.433822          2.8607       0.9410
# 11            Alameda          1.433822          2.8607       0.9410
# 12            Alameda          1.433822          2.8607       0.9410
# ...

# %%
combined_data.to_csv("combined_data.csv", encoding='utf-8', index=False)
